# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaeduardafelipe48/cnweb_2b2_b/blob/main/aula23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a,b):
  return (a+b)

# %%
soma(8, 45)
# Out:
# 53

# %% [markdown]
# # Sistema de Equações

# %%
from ast import Return
import math
def eq2grau(a,b,c):
  delta = b**2 - 4*a*c

if(delta < 0):
return'equação sem solução'
   else:
    x1 = (-b + math.sqrt(delta)) / (2*a)
    x2 = (-b - math.sqrt(delta)) / (2*a)
     return x1, x2
# Out:
#   File "/tmp/ipykernel_24226/2773142314.py", line 7
#     return'equação sem solução'
#     ^
# IndentationError: expected an indented block after 'if' statement on line 6
